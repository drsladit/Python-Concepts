# %%
# class Method: 
# Class method takes "cls" argument as defalut argument
# We need to use decorate the regular method with decorator to make it class method @classmethod

# %%
# Static mathod:
# If we are creating a method in a class and we are not using any instance "self" or "cls".
# then we should create that method as static method

# %%
class Employee:
    # Class Attributes/variables
    raise_amount = 1.04 # Use case 1
    no_of_emps = 0 # Use case 2
    
    # Initializing Class
    def __init__(self, fname, lname, pay):
        # Instance Attibutes/variables - values
        self.fname = fname
        self.lname = lname
        self.pay   = pay
        self.email = fname + "." + lname + "@company.com"
        
        Employee.no_of_emps += 1
    
    # Regular Methods - actions
    def fullname(self):
        return self.fname + " " + self.lname
    
    def apply_pay_raise(self):
        return self.pay*employee.raise_amount # (OR) self.pay*self.raise_amount are same.
    
    # Class method/actions
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amount = amount
        
    @classmethod
    def myfromstring(cls, emp_str):
        fname,lname,pay = emp_str.split("-")
        return cls(fname,lname,pay)
    
    @staticmethod
    def is_weekday(day):
        if day.weekday() == 5 or day.weekday() == 6:
            return False
        return True

# %%
# Instance creation
emp1 = Employee("Aditya", "Kothapalli", 90000)
emp2 = Employee("Kavyasree", "Kothapalli", 90000)

# %%
# without classmethod output when we access raise amount from class and instance variables
print(Employee.raise_amount)
print(emp1.raise_amount)
print(emp2.raise_amount)
# Out:
# 1.04
# 1.04
# 1.04

# %%
Employee.set_raise_amt(1.05) # Same as Employee.raiseamount = 1.05 # using class method setting raise amount

# %%
print(Employee.raise_amount)
print(emp1.raise_amount)
print(emp2.raise_amount)
# Out:
# 1.05
# 1.05
# 1.05

# %%
# Use case for @classmethod
# Suppose we are getting employee data from different sources and data differs

# %%
emp_str_1 = "Ram-nam-10000000"
emp_str_2 = "Govinda-nam-108"

# %%
# If we want to pass above staring data and create employee instance. We can use @classmethod

# %%
new_emp_1 = Employee.myfromstring(emp_str_1)

# %%
new_emp_1.email
# Out:
# 'Ram.nam@company.com'

# %%
print(Employee.__dict__)
# Out:
# {'__module__': '__main__', 'raise_amount': 1.04, 'no_of_emps': 1, '__init__': <function Employee.__init__ at 0x000002205504FF70>, 'fullname': <function Employee.fullname at 0x000002205504F820>, 'apply_pay_raise': <function Employee.apply_pay_raise at 0x000002205504FB80>, 'set_raise_amt': <classmethod object at 0x000002205525D070>, 'from_string': <classmethod object at 0x000002205525DF10>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %%
import datetime
my_date = datetime.date(2021, 9, 26)

print(Employee.is_weekday(my_date))
# Out:
# False
