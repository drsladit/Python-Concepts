# %%
class A:
    def __init__(self, name):
            self.name = name
    
    def p1(self):
        print("p1")

# %%
class B(A):
    def p1(self):
        print("p2")

# %%
class C(B):
    def p1(self):
        print("p3")

# %%
i = A("adi")

# %%
i.p1()
# Out:
# p1
