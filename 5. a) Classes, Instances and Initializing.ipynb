# %%
#Classes - Logically group data and functions and make us easy to reuse and easy to build i.e add or remove.
# __int__ method – This dunder/Special/magic method helps in declaring the attributes for each instance. 
#Instead of declaring them each time.

# %%
# Creating a Class
class Employee:
    
    # Initialising or constructor method - It is also a dunder method

    def __init__(self, fname, lname, pay):
        # Attibutes/variables/values for each instance
        self.fname = fname
        self.lname = lname
        self.pay   = pay
        self.email = fname + "." + lname + "@company.com"
        
    
    # Regular Methods/actions
    def fullname(self): # automatically takes in the instance as first argument i.e. "self"
        return self.fname + " " + self.lname
    
    def apply_pay_raise(self):
        return self.pay*employee.raise_amount # OR self.pay*self.raise_amount

# %%
# Instance creation
emp1 = Employee("Aditya", "Kothapalli", 90000)
emp2 = Employee("Kavyasree", "Kothapalli", 90000)

# %%
print(emp1)
print(emp2)
# We can see below that emp1 and emp2 are 2 objects/instances created at different address

# %%
#emp1.__dict__ # Name spaces for instance

# %%
#Employee.__dict__ # Name spaces for classes

# %%
# Accessing the attribites and Methods of the class for given instance

# %%
#emp1.fname

# %%
#emp1.lname

# %%
#emp1.pay

# %%
#emp1.email

# %%
#emp1.fullname()
