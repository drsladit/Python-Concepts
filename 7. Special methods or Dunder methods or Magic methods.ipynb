# %%
# Special methods:
# Special methods are inbuilt methods. These methods can be overwritten

# %%
# Creating a Class
class Employee:
    
    # Initialising or constructor method - It is also a dunder method

    def __init__(self, fname, lname, pay):
        # Attibutes/variables/values for each instance
        self.fname = fname
        self.lname = lname
        self.pay   = pay
        self.email = fname + "." + lname + "@company.com"
        
    
    # Regular Methods/actions
    def fullname(self):
        return self.fname + " " + self.lname
    
    def apply_pay_raise(self):
        return self.pay*self.raise_amount
    
    # Dunder/special method/magic method overwritting
    def __sizeof__(self):
        return "This method gives size of object if we don't override"

# %%
# Instance creation
emp1 = Employee("Aditya", "Kothapalli", 90000)
emp2 = Employee("Kavyasree", "Kothapalli", 90000)

# %%
#dir(emp1) # We can see __init__ also a inbulit methods for emp1 object

# %%
emp1.__str__()
# Out:
# '<__main__.Employee object at 0x0000022697950430>'

# %%
emp1.__sizeof__()
# Out:
# "This method gives size of object if we don't override"
