# %%
class A:
    def __init__(self, name):
            self.name = name
    
    def p1(self):
        print("p1")

# %%
class B(A):
    def p1(self):
        print("p1")

# %%
class C(B):
    def p1(self):
        print("p1")
