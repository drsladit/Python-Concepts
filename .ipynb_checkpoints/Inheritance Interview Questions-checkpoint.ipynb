# %%
class A:
    def __init__(self, name):
            self.name = name
    
    def p1(self):
        print("p1")

# %%
class B(A):
    def p1(self):
        print("p2")

# %%
class C(B):
    def p1(self):
        print("p3")

# %%
i = A("adi")

# %%
i.p1()
# Out:
# p1

# %%
print(help(C))
# Out:
# Help on class C in module __main__:
#
# class C(B)
#  |  C(name)
#  |
#  |  Method resolution order:
#  |      C
#  |      B
#  |      A
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  p1(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from A:
#  |
#  |  __init__(self, name)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from A:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None

# %%
class A1:
       
    def m(self):
        print("A")

# %%
class B1():

    def m(self):
        print("B")

# %%
class C1(A1):
    
    def m(self):
        print("C")

# %%
class D1(B1,C1):

    pass

# %%
print(help(D1))
# Out:
# Help on class D1 in module __main__:
#
# class D1(B1, C1)
#  |  Method resolution order:
#  |      D1
#  |      B1
#  |      C1
#  |      A1
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  a = 10
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from B1:
#  |
#  |  m(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from B1:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None
