# %%
# class variables/attribute can be used when we want attribute unique across all instances/initialization

# %%
class Employee:
    # Class Attributes/variables
    raise_amount = 1.04 # Use case 1
    no_of_emps = 0 # Use case 2
    
    # Initializing Class
    def __init__(self, fname, lname, pay):
        # Instance Attibutes/variables - values
        self.fname = fname
        self.lname = lname
        self.pay   = pay
        self.email = fname + "." + lname + "@company.com"
        
        Employee.no_of_emps += 1
        # Regular Methods - actions
    def fullname(self):
        return self.fname + " " + self.lname
    
    def apply_pay_raise(self):
        return self.pay*employee.raise_amount # (OR) self.pay*self.raise_amount are same.

# %%
emp1 = Employee("aditya", "kothapalli", 30000)
emp2 = Employee("kavyasree", "kothapalli", 25000)

# %%
# We can access this Class variable from both class and 2 instances
print(Employee.raise_amount)
print(emp1.raise_amount)
print(emp2.raise_amount)
# Out:
# 1.04
# 1.04
# 1.04

# %%
# but to know from where exactly this class variable is located or pulled from we can use __dict__ method
# we can see Class variable is available in class but not in instances
# To conculde: Each instance fisrt chesks in their instance attributes, Then in class variables, Then in parent class if any.
print(Employee.__dict__)
# Out:
# {'__module__': '__main__', 'raise_amount': 1.04, '__init__': <function Employee.__init__ at 0x000001DDDB98BE50>, 'fullname': <function Employee.fullname at 0x000001DDDB98BD30>, 'apply_pay_raise': <function Employee.apply_pay_raise at 0x000001DDDB98BEE0>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %%
print(emp1.__dict__)
print(emp2.__dict__)
# Out:
# {'fname': 'aditya', 'lname': 'kothapalli', 'pay': 30000, 'email': 'aditya.kothapalli@company.com'}
# {'fname': 'kavyasree', 'lname': 'kothapalli', 'pay': 25000, 'email': 'kavyasree.kothapalli@company.com'}

# %%
Employee.no_of_emps
# Out:
# 2
